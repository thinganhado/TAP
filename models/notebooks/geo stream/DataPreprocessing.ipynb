# %% [markdown]
# <h3><strong>STEP 1: Load Data from Folders</strong></h3>

# %%
import pandas as pd
import os
import glob

def load_geo_data(base_path):
    """
    Load geolocation data from all fold directories
    """
    # List all the fold directories
    fold_dirs = [f for f in os.listdir(base_path) if f.startswith('fold=')]
    print("Found folds:", fold_dirs)
    
    # Load and combine all data, adding a 'fold' column
    all_data_frames = []
    
    for fold_dir in fold_dirs:
        fold_number = int(fold_dir.split('=')[1])  # Extract the fold integer
        fold_path = os.path.join(base_path, fold_dir)
        
        # Find all parquet files with the specific naming pattern in this fold directory
        parquet_pattern = os.path.join(fold_path, "part-*.snappy.parquet")
        parquet_files = glob.glob(parquet_pattern)
        print(f"Found {len(parquet_files)} parquet files in {fold_dir}")
        
        # Load all parquet files for this fold
        fold_dfs = []
        for file_path in parquet_files:
            df = pd.read_parquet(file_path)
            fold_dfs.append(df)
        
        # Combine all files for this fold
        if fold_dfs:
            fold_df = pd.concat(fold_dfs, ignore_index=True)
            fold_df['fold'] = fold_number
            all_data_frames.append(fold_df)
    
    # Combine all folds into a single DataFrame
    if all_data_frames:
        geo_df = pd.concat(all_data_frames, ignore_index=True)
        print(f"Full dataset shape: {geo_df.shape}")
        print(f"Unique clients per fold: {geo_df.groupby('fold')['client_id'].nunique()}")
        
        # Display basic info about the loaded data
        print("\nFirst few rows of the combined data:")
        print(geo_df.head())
        print("\nColumn names:")
        print(geo_df.columns.tolist())
        
        return geo_df
    else:
        print("No data found. Please check the file paths.")
        return None

# Execute Step 1
base_path = r"/home/opc/datasets/detail/detail/detail/geo"
geo_df = load_geo_data(base_path)

# Save the raw loaded data
if geo_df is not None:
    geo_df.to_pickle("geo_data_raw.pkl")
    print("Raw data saved to geo_data_raw.pkl")
# Out:
# Found folds: ['fold=0', 'fold=1', 'fold=2', 'fold=3', 'fold=4']
# Found 92 parquet files in fold=0
# Found 92 parquet files in fold=1
# Found 92 parquet files in fold=2
# Found 92 parquet files in fold=3
# Found 92 parquet files in fold=4
# Full dataset shape: (66295724, 6)
# Unique clients per fold: fold
# 0    14863
# 1    14409
# 2    14396
# 3    14380
# 4    14525
# Name: client_id, dtype: int64
#
# First few rows of the combined data:
#                                            client_id  \
# 0  397d52b11ce72699a5482e5397f63a03af1636c85e9e61...
# 1  397d52b11ce72699a5482e5397f63a03af1636c85e9e61...
# 2  397d52b11ce72699a5482e5397f63a03af1636c85e9e61...
# 3  397d52b11ce72699a5482e5397f63a03af1636c85e9e61...
# 4  397d52b11ce72699a5482e5397f63a03af1636c85e9e61...
#
#                   event_time  geohash_4  geohash_5  geohash_6  fold
# 0 2022-03-25 13:39:51.569288      41342     406579    1018528     0
# 1 2022-06-11 07:21:32.505485      41342     406579    1018528     0
# 2 2022-08-08 21:25:07.461323      41342     406579    1018528     0
# 3 2022-07-23 11:32:03.433401      41342     406579    1018528     0
# 4 2022-05-28 08:18:19.843885      41342     406579    1018528     0
#
# Column names:
# ['client_id', 'event_time', 'geohash_4', 'geohash_5', 'geohash_6', 'fold']
# Raw data saved to geo_data_raw.pkl

# %% [markdown]
# <h3><strong>STEP 2: Preprocess Data (Explode Arrays and Convert Timestamps)</strong></h3>

# %%
import numpy as np
import pandas as pd
from pandas.api.types import is_list_like

# 1) choose a row that has multiple events if one exists
def _is_multi_event(x):
    return is_list_like(x) and not isinstance(x, (str, bytes)) and len(x) > 1

row_idx = 0
multi = geo_df[geo_df["event_time"].apply(_is_multi_event)]
if not multi.empty:
    row_idx = int(multi.index[0])  # use the first multi event row

# 2) run your existing function on that row
test_result = test_corrected_explosion(geo_df, row_index=row_idx)

# 3) only try to decode plausible geohashes, compute the right denominator
alphabet = set("0123456789bcdefghjkmnpqrstuvwxyz")
def looks_like_geohash(v):
    if pd.isna(v):
        return False
    s = str(v).strip().lower()
    if len(s) == 0 or len(s) > 12:
        return False
    return set(s).issubset(alphabet)

# pick up to 20 candidates from the exploded rows
cands = test_result["geohash_6"].head(20)
valid_mask = cands.apply(looks_like_geohash)
subset = cands[valid_mask]

print(f"\nDecoding up to {len(cands)} values, {len(subset)} look like valid base32 geohash strings")

# robust geohash import
try:
    import geohash as gh
except Exception:
    try:
        import Geohash as gh
    except Exception:
        import pygeohash as gh

def decode_geohash_value(val):
    try:
        s = str(val).strip().lower()
        lat, lon = gh.decode(s)
        return lat, lon
    except Exception as e:
        return (np.nan, np.nan)

success = 0
total = max(1, len(subset))  # avoid zero division
for i, val in enumerate(subset):
    latlon = decode_geohash_value(val)
    ok = not pd.isna(latlon[0])
    success += int(ok)
    print(f"geohash_6[{i}]: {val} -> {latlon} {'OK' if ok else 'FAIL'}")

print(f"\nSuccessful decodes: {success}/{total}")
# Out:
# Testing corrected explosion on first row...
# Original row shape: (1, 6)
# Number of events in this client: 1
# Exploded row shape: (1, 6)
#
# Decoding up to 1 values, 1 look like valid base32 geohash strings
# geohash_6[0]: 1018528 -> (-89.99656677246094, -132.7471160888672) OK
#
# Successful decodes: 1/1

# %%
import pandas as pd
import numpy as np
import os
import glob
from pandas.api.types import is_list_like

# paths, set to where your data lives
INPUT_PICKLE = "/home/opc/datasets/detail/geo_data_raw.pkl"
OUTPUT_DIR   = "/home/opc/datasets/detail/processing_batches"
COMBINED_OUT = "/home/opc/datasets/detail/geo_data_preprocessed.pkl"

def _to_dt_list(x):
    # accepts scalar unix seconds, Timestamp, or list of either
    if isinstance(x, pd.Timestamp):
        return [x]
    if not is_list_like(x) or isinstance(x, (str, bytes)):
        return [pd.to_datetime(x, unit="s", errors="coerce")]
    return [ts if isinstance(ts, pd.Timestamp) else pd.to_datetime(ts, unit="s", errors="coerce") for ts in x]

def _to_list(x):
    # ensures list for geohash columns
    if x is None or (isinstance(x, float) and pd.isna(x)):
        return []
    if is_list_like(x) and not isinstance(x, (str, bytes)):
        return list(x)
    return [x]

# Explode all nested arrays for the entire dataset
def preprocess_geo_data_corrected(geo_df, batch_size=2500, output_dir=OUTPUT_DIR):
    os.makedirs(output_dir, exist_ok=True)

    total_rows = len(geo_df)
    num_batches = (total_rows + batch_size - 1) // batch_size
    print(f"Processing {total_rows} rows in {num_batches} batches of size {batch_size}")

    all_batch_files = []

    for batch_num in range(num_batches):
        print(f"Processing batch {batch_num+1}/{num_batches}")
        start_idx = batch_num * batch_size
        end_idx = min((batch_num + 1) * batch_size, total_rows)
        batch_df = geo_df.iloc[start_idx:end_idx].copy()

        # convert event_time safely, only on this batch
        batch_df["event_time"] = batch_df["event_time"].apply(_to_dt_list)

        # ensure geohash columns are list like for this batch
        for col in ["geohash_4", "geohash_5", "geohash_6"]:
            if col in batch_df.columns:
                batch_df[col] = batch_df[col].apply(_to_list)

        # explode using a simple Python loop per row, ok in batches
        exploded_rows = []
        for _, row in batch_df.iterrows():
            n_events = len(row["event_time"])
            for i in range(n_events):
                exploded_rows.append({
                    "client_id": row["client_id"],
                    "event_time": row["event_time"][i],
                    "geohash_4": row["geohash_4"][i] if i < len(row["geohash_4"]) else None,
                    "geohash_5": row["geohash_5"][i] if i < len(row["geohash_5"]) else None,
                    "geohash_6": row["geohash_6"][i] if i < len(row["geohash_6"]) else None,
                    "fold": row["fold"],
                })

        batch_exploded = pd.DataFrame(exploded_rows)

        batch_filename = os.path.join(output_dir, f"batch_{batch_num+1}_of_{num_batches}.pkl")
        batch_exploded.to_pickle(batch_filename)
        all_batch_files.append(batch_filename)

        print(f"Batch {batch_num+1} saved to {batch_filename}")
        print(f"  Exploded from {len(batch_df)} to {len(batch_exploded)} rows")

        del batch_df, batch_exploded, exploded_rows

    return all_batch_files

def combine_batches(batch_files, output_file=COMBINED_OUT):
    print("Combining all batches...")
    all_batches = [pd.read_pickle(bf) for bf in batch_files]
    geo_df_exploded = pd.concat(all_batches, ignore_index=True)
    print(f"Combined dataset shape: {geo_df_exploded.shape}")
    geo_df_exploded.to_pickle(output_file)
    print(f"Combined data saved to {output_file}")
    return geo_df_exploded

# load if needed
try:
    geo_df
except NameError:
    geo_df = pd.read_pickle(INPUT_PICKLE)

# tune batch size if RAM is tight
batch_files = preprocess_geo_data_corrected(geo_df, batch_size=2500, output_dir=OUTPUT_DIR)
geo_df_exploded = combine_batches(batch_files, output_file=COMBINED_OUT)
print("Step 2 completed successfully!")
# Out:
# Processing 66295724 rows in 26519 batches of size 2500
# Processing batch 1/26519
# Batch 1 saved to /home/opc/datasets/detail/processing_batches/batch_1_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 2/26519
# Batch 2 saved to /home/opc/datasets/detail/processing_batches/batch_2_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 3/26519
# Batch 3 saved to /home/opc/datasets/detail/processing_batches/batch_3_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 4/26519
# Batch 4 saved to /home/opc/datasets/detail/processing_batches/batch_4_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 5/26519
# Batch 5 saved to /home/opc/datasets/detail/processing_batches/batch_5_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 6/26519
# Batch 6 saved to /home/opc/datasets/detail/processing_batches/batch_6_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 7/26519
# Batch 7 saved to /home/opc/datasets/detail/processing_batches/batch_7_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 8/26519
# Batch 8 saved to /home/opc/datasets/detail/processing_batches/batch_8_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 9/26519
# Batch 9 saved to /home/opc/datasets/detail/processing_batches/batch_9_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 10/26519
# Batch 10 saved to /home/opc/datasets/detail/processing_batches/batch_10_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 11/26519
# Batch 11 saved to /home/opc/datasets/detail/processing_batches/batch_11_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 12/26519
# Batch 12 saved to /home/opc/datasets/detail/processing_batches/batch_12_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 13/26519
# Batch 13 saved to /home/opc/datasets/detail/processing_batches/batch_13_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 14/26519
# Batch 14 saved to /home/opc/datasets/detail/processing_batches/batch_14_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 15/26519
# Batch 15 saved to /home/opc/datasets/detail/processing_batches/batch_15_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 16/26519
# Batch 16 saved to /home/opc/datasets/detail/processing_batches/batch_16_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 17/26519
# Batch 17 saved to /home/opc/datasets/detail/processing_batches/batch_17_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 18/26519
# Batch 18 saved to /home/opc/datasets/detail/processing_batches/batch_18_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 19/26519
# Batch 19 saved to /home/opc/datasets/detail/processing_batches/batch_19_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 20/26519
# Batch 20 saved to /home/opc/datasets/detail/processing_batches/batch_20_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 21/26519
# Batch 21 saved to /home/opc/datasets/detail/processing_batches/batch_21_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 22/26519
# Batch 22 saved to /home/opc/datasets/detail/processing_batches/batch_22_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 23/26519
# Batch 23 saved to /home/opc/datasets/detail/processing_batches/batch_23_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 24/26519
# Batch 24 saved to /home/opc/datasets/detail/processing_batches/batch_24_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 25/26519
# Batch 25 saved to /home/opc/datasets/detail/processing_batches/batch_25_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26/26519
# Batch 26 saved to /home/opc/datasets/detail/processing_batches/batch_26_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 27/26519
# Batch 27 saved to /home/opc/datasets/detail/processing_batches/batch_27_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 28/26519
# Batch 28 saved to /home/opc/datasets/detail/processing_batches/batch_28_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 29/26519
# Batch 29 saved to /home/opc/datasets/detail/processing_batches/batch_29_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 30/26519
# Batch 30 saved to /home/opc/datasets/detail/processing_batches/batch_30_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 31/26519
# Batch 31 saved to /home/opc/datasets/detail/processing_batches/batch_31_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 32/26519
# Batch 32 saved to /home/opc/datasets/detail/processing_batches/batch_32_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 33/26519
# Batch 33 saved to /home/opc/datasets/detail/processing_batches/batch_33_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 34/26519
# Batch 34 saved to /home/opc/datasets/detail/processing_batches/batch_34_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 35/26519
# Batch 35 saved to /home/opc/datasets/detail/processing_batches/batch_35_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 36/26519
# Batch 36 saved to /home/opc/datasets/detail/processing_batches/batch_36_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 37/26519
# Batch 37 saved to /home/opc/datasets/detail/processing_batches/batch_37_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 38/26519
# Batch 38 saved to /home/opc/datasets/detail/processing_batches/batch_38_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 39/26519
# Batch 39 saved to /home/opc/datasets/detail/processing_batches/batch_39_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 40/26519
# Batch 40 saved to /home/opc/datasets/detail/processing_batches/batch_40_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 41/26519
# Batch 41 saved to /home/opc/datasets/detail/processing_batches/batch_41_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 42/26519
# Batch 42 saved to /home/opc/datasets/detail/processing_batches/batch_42_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 43/26519
# Batch 43 saved to /home/opc/datasets/detail/processing_batches/batch_43_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 44/26519
# Batch 44 saved to /home/opc/datasets/detail/processing_batches/batch_44_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 45/26519
# Batch 45 saved to /home/opc/datasets/detail/processing_batches/batch_45_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 46/26519
# Batch 46 saved to /home/opc/datasets/detail/processing_batches/batch_46_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 47/26519
# Batch 47 saved to /home/opc/datasets/detail/processing_batches/batch_47_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 48/26519
# Batch 48 saved to /home/opc/datasets/detail/processing_batches/batch_48_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 49/26519
# Batch 49 saved to /home/opc/datasets/detail/processing_batches/batch_49_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 50/26519
# Batch 50 saved to /home/opc/datasets/detail/processing_batches/batch_50_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 51/26519
# Batch 51 saved to /home/opc/datasets/detail/processing_batches/batch_51_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 52/26519
# Batch 52 saved to /home/opc/datasets/detail/processing_batches/batch_52_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 53/26519
# Batch 53 saved to /home/opc/datasets/detail/processing_batches/batch_53_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 54/26519
# Batch 54 saved to /home/opc/datasets/detail/processing_batches/batch_54_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 55/26519
# Batch 55 saved to /home/opc/datasets/detail/processing_batches/batch_55_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 56/26519
# Batch 56 saved to /home/opc/datasets/detail/processing_batches/batch_56_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 57/26519
# Batch 57 saved to /home/opc/datasets/detail/processing_batches/batch_57_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 58/26519
# Batch 58 saved to /home/opc/datasets/detail/processing_batches/batch_58_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 59/26519
# Batch 59 saved to /home/opc/datasets/detail/processing_batches/batch_59_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 60/26519
# Batch 60 saved to /home/opc/datasets/detail/processing_batches/batch_60_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 61/26519
# Batch 61 saved to /home/opc/datasets/detail/processing_batches/batch_61_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 62/26519
# Batch 62 saved to /home/opc/datasets/detail/processing_batches/batch_62_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 63/26519
# Batch 63 saved to /home/opc/datasets/detail/processing_batches/batch_63_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 64/26519
# Batch 64 saved to /home/opc/datasets/detail/processing_batches/batch_64_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 65/26519
# Batch 65 saved to /home/opc/datasets/detail/processing_batches/batch_65_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 66/26519
# Batch 66 saved to /home/opc/datasets/detail/processing_batches/batch_66_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 67/26519
# Batch 67 saved to /home/opc/datasets/detail/processing_batches/batch_67_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 68/26519
# Batch 68 saved to /home/opc/datasets/detail/processing_batches/batch_68_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 69/26519
# Batch 69 saved to /home/opc/datasets/detail/processing_batches/batch_69_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 70/26519
# Batch 70 saved to /home/opc/datasets/detail/processing_batches/batch_70_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 71/26519
# Batch 71 saved to /home/opc/datasets/detail/processing_batches/batch_71_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 72/26519
# Batch 72 saved to /home/opc/datasets/detail/processing_batches/batch_72_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 73/26519
# Batch 73 saved to /home/opc/datasets/detail/processing_batches/batch_73_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 74/26519
# Batch 74 saved to /home/opc/datasets/detail/processing_batches/batch_74_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 75/26519
# Batch 75 saved to /home/opc/datasets/detail/processing_batches/batch_75_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 76/26519
# Batch 76 saved to /home/opc/datasets/detail/processing_batches/batch_76_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 77/26519
# Batch 77 saved to /home/opc/datasets/detail/processing_batches/batch_77_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 78/26519
# Batch 78 saved to /home/opc/datasets/detail/processing_batches/batch_78_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 79/26519
# Batch 79 saved to /home/opc/datasets/detail/processing_batches/batch_79_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 80/26519
# Batch 80 saved to /home/opc/datasets/detail/processing_batches/batch_80_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 81/26519
# Batch 81 saved to /home/opc/datasets/detail/processing_batches/batch_81_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 82/26519
# Batch 82 saved to /home/opc/datasets/detail/processing_batches/batch_82_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 83/26519
# Batch 83 saved to /home/opc/datasets/detail/processing_batches/batch_83_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 84/26519
# Batch 84 saved to /home/opc/datasets/detail/processing_batches/batch_84_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 85/26519
# Batch 85 saved to /home/opc/datasets/detail/processing_batches/batch_85_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 86/26519
# Batch 86 saved to /home/opc/datasets/detail/processing_batches/batch_86_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 87/26519
# Batch 87 saved to /home/opc/datasets/detail/processing_batches/batch_87_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 88/26519
# Batch 88 saved to /home/opc/datasets/detail/processing_batches/batch_88_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 89/26519
# Batch 89 saved to /home/opc/datasets/detail/processing_batches/batch_89_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 90/26519
# Batch 90 saved to /home/opc/datasets/detail/processing_batches/batch_90_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 91/26519
# Batch 91 saved to /home/opc/datasets/detail/processing_batches/batch_91_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 92/26519
# Batch 92 saved to /home/opc/datasets/detail/processing_batches/batch_92_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 93/26519
# Batch 93 saved to /home/opc/datasets/detail/processing_batches/batch_93_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 94/26519
# Batch 94 saved to /home/opc/datasets/detail/processing_batches/batch_94_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 95/26519
# Batch 95 saved to /home/opc/datasets/detail/processing_batches/batch_95_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 96/26519
# Batch 96 saved to /home/opc/datasets/detail/processing_batches/batch_96_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 97/26519
# Batch 97 saved to /home/opc/datasets/detail/processing_batches/batch_97_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 98/26519
# Batch 98 saved to /home/opc/datasets/detail/processing_batches/batch_98_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 99/26519
# Batch 99 saved to /home/opc/datasets/detail/processing_batches/batch_99_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 100/26519
# Batch 100 saved to /home/opc/datasets/detail/processing_batches/batch_100_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 101/26519
# Batch 101 saved to /home/opc/datasets/detail/processing_batches/batch_101_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 102/26519
# Batch 102 saved to /home/opc/datasets/detail/processing_batches/batch_102_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 103/26519
# Batch 103 saved to /home/opc/datasets/detail/processing_batches/batch_103_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 104/26519
# Batch 104 saved to /home/opc/datasets/detail/processing_batches/batch_104_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 105/26519
# Batch 105 saved to /home/opc/datasets/detail/processing_batches/batch_105_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 106/26519
# Batch 106 saved to /home/opc/datasets/detail/processing_batches/batch_106_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 107/26519
# Batch 107 saved to /home/opc/datasets/detail/processing_batches/batch_107_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 108/26519
# Batch 108 saved to /home/opc/datasets/detail/processing_batches/batch_108_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 109/26519
# Batch 109 saved to /home/opc/datasets/detail/processing_batches/batch_109_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 110/26519
# Batch 110 saved to /home/opc/datasets/detail/processing_batches/batch_110_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 111/26519
# Batch 111 saved to /home/opc/datasets/detail/processing_batches/batch_111_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 112/26519
# Batch 112 saved to /home/opc/datasets/detail/processing_batches/batch_112_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 113/26519
# Batch 113 saved to /home/opc/datasets/detail/processing_batches/batch_113_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 114/26519
# Batch 114 saved to /home/opc/datasets/detail/processing_batches/batch_114_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 115/26519
# Batch 115 saved to /home/opc/datasets/detail/processing_batches/batch_115_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 116/26519
# Batch 116 saved to /home/opc/datasets/detail/processing_batches/batch_116_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 117/26519
# Batch 117 saved to /home/opc/datasets/detail/processing_batches/batch_117_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 118/26519
# Batch 118 saved to /home/opc/datasets/detail/processing_batches/batch_118_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 119/26519
# Batch 119 saved to /home/opc/datasets/detail/processing_batches/batch_119_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 120/26519
# Batch 120 saved to /home/opc/datasets/detail/processing_batches/batch_120_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 121/26519
# Batch 121 saved to /home/opc/datasets/detail/processing_batches/batch_121_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 122/26519
# Batch 122 saved to /home/opc/datasets/detail/processing_batches/batch_122_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 123/26519
# Batch 123 saved to /home/opc/datasets/detail/processing_batches/batch_123_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 124/26519
# Batch 124 saved to /home/opc/datasets/detail/processing_batches/batch_124_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 125/26519
# Batch 125 saved to /home/opc/datasets/detail/processing_batches/batch_125_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 126/26519
# Batch 126 saved to /home/opc/datasets/detail/processing_batches/batch_126_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 127/26519
# Batch 127 saved to /home/opc/datasets/detail/processing_batches/batch_127_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 128/26519
# Batch 128 saved to /home/opc/datasets/detail/processing_batches/batch_128_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 129/26519
# Batch 129 saved to /home/opc/datasets/detail/processing_batches/batch_129_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 130/26519
# Batch 130 saved to /home/opc/datasets/detail/processing_batches/batch_130_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 131/26519
# Batch 131 saved to /home/opc/datasets/detail/processing_batches/batch_131_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 132/26519
# Batch 132 saved to /home/opc/datasets/detail/processing_batches/batch_132_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 133/26519
# Batch 133 saved to /home/opc/datasets/detail/processing_batches/batch_133_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 134/26519
# Batch 134 saved to /home/opc/datasets/detail/processing_batches/batch_134_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 135/26519
# Batch 135 saved to /home/opc/datasets/detail/processing_batches/batch_135_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 136/26519
# Batch 136 saved to /home/opc/datasets/detail/processing_batches/batch_136_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 137/26519
# Batch 137 saved to /home/opc/datasets/detail/processing_batches/batch_137_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 138/26519
# Batch 138 saved to /home/opc/datasets/detail/processing_batches/batch_138_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 139/26519
# Batch 139 saved to /home/opc/datasets/detail/processing_batches/batch_139_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 140/26519
# Batch 140 saved to /home/opc/datasets/detail/processing_batches/batch_140_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 141/26519
# Batch 141 saved to /home/opc/datasets/detail/processing_batches/batch_141_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 142/26519
# Batch 142 saved to /home/opc/datasets/detail/processing_batches/batch_142_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 143/26519
# Batch 143 saved to /home/opc/datasets/detail/processing_batches/batch_143_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 144/26519
# Batch 144 saved to /home/opc/datasets/detail/processing_batches/batch_144_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 145/26519
# Batch 145 saved to /home/opc/datasets/detail/processing_batches/batch_145_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 146/26519
# Batch 146 saved to /home/opc/datasets/detail/processing_batches/batch_146_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 147/26519
# Batch 147 saved to /home/opc/datasets/detail/processing_batches/batch_147_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 148/26519
# Batch 148 saved to /home/opc/datasets/detail/processing_batches/batch_148_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 149/26519
# Batch 149 saved to /home/opc/datasets/detail/processing_batches/batch_149_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 150/26519
# Batch 150 saved to /home/opc/datasets/detail/processing_batches/batch_150_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 151/26519
# Batch 151 saved to /home/opc/datasets/detail/processing_batches/batch_151_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 152/26519
# Batch 152 saved to /home/opc/datasets/detail/processing_batches/batch_152_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 153/26519
# Batch 153 saved to /home/opc/datasets/detail/processing_batches/batch_153_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 154/26519
# Batch 154 saved to /home/opc/datasets/detail/processing_batches/batch_154_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 155/26519
# Batch 155 saved to /home/opc/datasets/detail/processing_batches/batch_155_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 156/26519
# Batch 156 saved to /home/opc/datasets/detail/processing_batches/batch_156_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 157/26519
# Batch 157 saved to /home/opc/datasets/detail/processing_batches/batch_157_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 158/26519
# Batch 158 saved to /home/opc/datasets/detail/processing_batches/batch_158_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 159/26519
# Batch 159 saved to /home/opc/datasets/detail/processing_batches/batch_159_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 160/26519
# Batch 160 saved to /home/opc/datasets/detail/processing_batches/batch_160_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 161/26519
# Batch 161 saved to /home/opc/datasets/detail/processing_batches/batch_161_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 162/26519
# Batch 162 saved to /home/opc/datasets/detail/processing_batches/batch_162_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 163/26519
# Batch 163 saved to /home/opc/datasets/detail/processing_batches/batch_163_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 164/26519
# Batch 164 saved to /home/opc/datasets/detail/processing_batches/batch_164_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 165/26519
# Batch 165 saved to /home/opc/datasets/detail/processing_batches/batch_165_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 166/26519
# Batch 166 saved to /home/opc/datasets/detail/processing_batches/batch_166_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 167/26519
# Batch 167 saved to /home/opc/datasets/detail/processing_batches/batch_167_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 168/26519
# Batch 168 saved to /home/opc/datasets/detail/processing_batches/batch_168_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 169/26519
# Batch 169 saved to /home/opc/datasets/detail/processing_batches/batch_169_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 170/26519
# Batch 170 saved to /home/opc/datasets/detail/processing_batches/batch_170_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 171/26519
# Batch 171 saved to /home/opc/datasets/detail/processing_batches/batch_171_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 172/26519
# Batch 172 saved to /home/opc/datasets/detail/processing_batches/batch_172_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 173/26519
# Batch 173 saved to /home/opc/datasets/detail/processing_batches/batch_173_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 174/26519
# Batch 174 saved to /home/opc/datasets/detail/processing_batches/batch_174_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 175/26519
# Batch 175 saved to /home/opc/datasets/detail/processing_batches/batch_175_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 176/26519
# Batch 176 saved to /home/opc/datasets/detail/processing_batches/batch_176_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 177/26519
# Batch 177 saved to /home/opc/datasets/detail/processing_batches/batch_177_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 178/26519
# Batch 178 saved to /home/opc/datasets/detail/processing_batches/batch_178_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 179/26519
# Batch 179 saved to /home/opc/datasets/detail/processing_batches/batch_179_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 180/26519
# Batch 180 saved to /home/opc/datasets/detail/processing_batches/batch_180_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 181/26519
# Batch 181 saved to /home/opc/datasets/detail/processing_batches/batch_181_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 182/26519
# Batch 182 saved to /home/opc/datasets/detail/processing_batches/batch_182_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 183/26519
# Batch 183 saved to /home/opc/datasets/detail/processing_batches/batch_183_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 184/26519
# Batch 184 saved to /home/opc/datasets/detail/processing_batches/batch_184_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 185/26519
# Batch 185 saved to /home/opc/datasets/detail/processing_batches/batch_185_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 186/26519
# Batch 186 saved to /home/opc/datasets/detail/processing_batches/batch_186_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 187/26519
# Batch 187 saved to /home/opc/datasets/detail/processing_batches/batch_187_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 188/26519
# Batch 188 saved to /home/opc/datasets/detail/processing_batches/batch_188_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 189/26519
# Batch 189 saved to /home/opc/datasets/detail/processing_batches/batch_189_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 190/26519
# Batch 190 saved to /home/opc/datasets/detail/processing_batches/batch_190_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 191/26519
# Batch 191 saved to /home/opc/datasets/detail/processing_batches/batch_191_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 192/26519
# Batch 192 saved to /home/opc/datasets/detail/processing_batches/batch_192_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 193/26519
# Batch 193 saved to /home/opc/datasets/detail/processing_batches/batch_193_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 194/26519
# Batch 194 saved to /home/opc/datasets/detail/processing_batches/batch_194_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 195/26519
# Batch 195 saved to /home/opc/datasets/detail/processing_batches/batch_195_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 196/26519
# Batch 196 saved to /home/opc/datasets/detail/processing_batches/batch_196_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 197/26519
# Batch 197 saved to /home/opc/datasets/detail/processing_batches/batch_197_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 198/26519
# Batch 198 saved to /home/opc/datasets/detail/processing_batches/batch_198_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 199/26519
# Batch 199 saved to /home/opc/datasets/detail/processing_batches/batch_199_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 200/26519
# Batch 200 saved to /home/opc/datasets/detail/processing_batches/batch_200_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 201/26519
# Batch 201 saved to /home/opc/datasets/detail/processing_batches/batch_201_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 202/26519
# Batch 202 saved to /home/opc/datasets/detail/processing_batches/batch_202_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 203/26519
# Batch 203 saved to /home/opc/datasets/detail/processing_batches/batch_203_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 204/26519
# Batch 204 saved to /home/opc/datasets/detail/processing_batches/batch_204_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 205/26519
# Batch 205 saved to /home/opc/datasets/detail/processing_batches/batch_205_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 206/26519
# Batch 206 saved to /home/opc/datasets/detail/processing_batches/batch_206_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 207/26519
# Batch 207 saved to /home/opc/datasets/detail/processing_batches/batch_207_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 208/26519
# Batch 208 saved to /home/opc/datasets/detail/processing_batches/batch_208_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 209/26519
# Batch 209 saved to /home/opc/datasets/detail/processing_batches/batch_209_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 210/26519
# Batch 210 saved to /home/opc/datasets/detail/processing_batches/batch_210_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 211/26519
# Batch 211 saved to /home/opc/datasets/detail/processing_batches/batch_211_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 212/26519
# Batch 212 saved to /home/opc/datasets/detail/processing_batches/batch_212_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 213/26519
# Batch 213 saved to /home/opc/datasets/detail/processing_batches/batch_213_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 214/26519
# Batch 214 saved to /home/opc/datasets/detail/processing_batches/batch_214_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 215/26519
# Batch 215 saved to /home/opc/datasets/detail/processing_batches/batch_215_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 216/26519
# Batch 216 saved to /home/opc/datasets/detail/processing_batches/batch_216_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 217/26519
# Batch 217 saved to /home/opc/datasets/detail/processing_batches/batch_217_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 218/26519
# Batch 218 saved to /home/opc/datasets/detail/processing_batches/batch_218_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 219/26519
# Batch 219 saved to /home/opc/datasets/detail/processing_batches/batch_219_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 220/26519
# Batch 220 saved to /home/opc/datasets/detail/processing_batches/batch_220_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 221/26519
# Batch 221 saved to /home/opc/datasets/detail/processing_batches/batch_221_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 222/26519
# Batch 222 saved to /home/opc/datasets/detail/processing_batches/batch_222_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 223/26519
# Batch 223 saved to /home/opc/datasets/detail/processing_batches/batch_223_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 224/26519
# Batch 224 saved to /home/opc/datasets/detail/processing_batches/batch_224_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 225/26519
# Batch 225 saved to /home/opc/datasets/detail/processing_batches/batch_225_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 226/26519
# Batch 226 saved to /home/opc/datasets/detail/processing_batches/batch_226_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 227/26519
# Batch 227 saved to /home/opc/datasets/detail/processing_batches/batch_227_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 228/26519
# Batch 228 saved to /home/opc/datasets/detail/processing_batches/batch_228_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 229/26519
# Batch 229 saved to /home/opc/datasets/detail/processing_batches/batch_229_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 230/26519
# Batch 230 saved to /home/opc/datasets/detail/processing_batches/batch_230_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 231/26519
# Batch 231 saved to /home/opc/datasets/detail/processing_batches/batch_231_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 232/26519
# Batch 232 saved to /home/opc/datasets/detail/processing_batches/batch_232_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 233/26519
# Batch 233 saved to /home/opc/datasets/detail/processing_batches/batch_233_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 234/26519
# Batch 234 saved to /home/opc/datasets/detail/processing_batches/batch_234_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 235/26519
# Batch 235 saved to /home/opc/datasets/detail/processing_batches/batch_235_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 236/26519
# Batch 236 saved to /home/opc/datasets/detail/processing_batches/batch_236_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 237/26519
# Batch 237 saved to /home/opc/datasets/detail/processing_batches/batch_237_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 238/26519
# Batch 238 saved to /home/opc/datasets/detail/processing_batches/batch_238_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 239/26519
# Batch 239 saved to /home/opc/datasets/detail/processing_batches/batch_239_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 240/26519
# Batch 240 saved to /home/opc/datasets/detail/processing_batches/batch_240_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 241/26519
# Batch 241 saved to /home/opc/datasets/detail/processing_batches/batch_241_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 242/26519
# Batch 242 saved to /home/opc/datasets/detail/processing_batches/batch_242_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 243/26519
# Batch 243 saved to /home/opc/datasets/detail/processing_batches/batch_243_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 244/26519
# Batch 244 saved to /home/opc/datasets/detail/processing_batches/batch_244_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 245/26519
# Batch 245 saved to /home/opc/datasets/detail/processing_batches/batch_245_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 246/26519
# Batch 246 saved to /home/opc/datasets/detail/processing_batches/batch_246_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 247/26519
# Batch 247 saved to /home/opc/datasets/detail/processing_batches/batch_247_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 248/26519
# Batch 248 saved to /home/opc/datasets/detail/processing_batches/batch_248_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 249/26519
# Batch 249 saved to /home/opc/datasets/detail/processing_batches/batch_249_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 250/26519
# Batch 250 saved to /home/opc/datasets/detail/processing_batches/batch_250_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 251/26519
# Batch 251 saved to /home/opc/datasets/detail/processing_batches/batch_251_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 252/26519
# Batch 252 saved to /home/opc/datasets/detail/processing_batches/batch_252_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 253/26519
# Batch 253 saved to /home/opc/datasets/detail/processing_batches/batch_253_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 254/26519
# Batch 254 saved to /home/opc/datasets/detail/processing_batches/batch_254_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 255/26519
# Batch 255 saved to /home/opc/datasets/detail/processing_batches/batch_255_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 256/26519
# Batch 256 saved to /home/opc/datasets/detail/processing_batches/batch_256_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 257/26519
# Batch 257 saved to /home/opc/datasets/detail/processing_batches/batch_257_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 258/26519
# Batch 258 saved to /home/opc/datasets/detail/processing_batches/batch_258_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 259/26519
# Batch 259 saved to /home/opc/datasets/detail/processing_batches/batch_259_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 260/26519
# Batch 260 saved to /home/opc/datasets/detail/processing_batches/batch_260_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 261/26519
# Batch 261 saved to /home/opc/datasets/detail/processing_batches/batch_261_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 262/26519
# Batch 262 saved to /home/opc/datasets/detail/processing_batches/batch_262_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 263/26519
# Batch 263 saved to /home/opc/datasets/detail/processing_batches/batch_263_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 264/26519
# Batch 264 saved to /home/opc/datasets/detail/processing_batches/batch_264_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 265/26519
# Batch 265 saved to /home/opc/datasets/detail/processing_batches/batch_265_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 266/26519
# Batch 266 saved to /home/opc/datasets/detail/processing_batches/batch_266_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 267/26519
# Batch 267 saved to /home/opc/datasets/detail/processing_batches/batch_267_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 268/26519
# Batch 268 saved to /home/opc/datasets/detail/processing_batches/batch_268_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 269/26519
# Batch 269 saved to /home/opc/datasets/detail/processing_batches/batch_269_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 270/26519
# Batch 270 saved to /home/opc/datasets/detail/processing_batches/batch_270_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 271/26519
# Batch 271 saved to /home/opc/datasets/detail/processing_batches/batch_271_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 272/26519
# Batch 272 saved to /home/opc/datasets/detail/processing_batches/batch_272_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 273/26519
# Batch 273 saved to /home/opc/datasets/detail/processing_batches/batch_273_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 274/26519
# Batch 274 saved to /home/opc/datasets/detail/processing_batches/batch_274_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 275/26519
# Batch 275 saved to /home/opc/datasets/detail/processing_batches/batch_275_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 276/26519
# Batch 276 saved to /home/opc/datasets/detail/processing_batches/batch_276_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 277/26519
# Batch 277 saved to /home/opc/datasets/detail/processing_batches/batch_277_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 278/26519
# Batch 278 saved to /home/opc/datasets/detail/processing_batches/batch_278_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 279/26519
# Batch 279 saved to /home/opc/datasets/detail/processing_batches/batch_279_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 280/26519
# Batch 280 saved to /home/opc/datasets/detail/processing_batches/batch_280_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 281/26519
# Batch 281 saved to /home/opc/datasets/detail/processing_batches/batch_281_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 282/26519
# Batch 282 saved to /home/opc/datasets/detail/processing_batches/batch_282_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 283/26519
# Batch 283 saved to /home/opc/datasets/detail/processing_batches/batch_283_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 284/26519
# Batch 284 saved to /home/opc/datasets/detail/processing_batches/batch_284_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 285/26519
# Batch 285 saved to /home/opc/datasets/detail/processing_batches/batch_285_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 286/26519
# Batch 286 saved to /home/opc/datasets/detail/processing_batches/batch_286_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 287/26519
# Batch 287 saved to /home/opc/datasets/detail/processing_batches/batch_287_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 288/26519
# Batch 288 saved to /home/opc/datasets/detail/processing_batches/batch_288_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 289/26519
# Batch 289 saved to /home/opc/datasets/detail/processing_batches/batch_289_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 290/26519
# Batch 290 saved to /home/opc/datasets/detail/processing_batches/batch_290_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 291/26519
# Batch 291 saved to /home/opc/datasets/detail/processing_batches/batch_291_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 292/26519
# Batch 292 saved to /home/opc/datasets/detail/processing_batches/batch_292_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 293/26519
# Batch 293 saved to /home/opc/datasets/detail/processing_batches/batch_293_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 294/26519
# Batch 294 saved to /home/opc/datasets/detail/processing_batches/batch_294_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 295/26519
# Batch 295 saved to /home/opc/datasets/detail/processing_batches/batch_295_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 296/26519
# Batch 296 saved to /home/opc/datasets/detail/processing_batches/batch_296_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 297/26519
# Batch 297 saved to /home/opc/datasets/detail/processing_batches/batch_297_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 298/26519
# Batch 298 saved to /home/opc/datasets/detail/processing_batches/batch_298_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 299/26519
# Batch 299 saved to /home/opc/datasets/detail/processing_batches/batch_299_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 300/26519
# Batch 300 saved to /home/opc/datasets/detail/processing_batches/batch_300_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 301/26519
# Batch 301 saved to /home/opc/datasets/detail/processing_batches/batch_301_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 302/26519
# Batch 302 saved to /home/opc/datasets/detail/processing_batches/batch_302_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 303/26519
# Batch 303 saved to /home/opc/datasets/detail/processing_batches/batch_303_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 304/26519
# Batch 304 saved to /home/opc/datasets/detail/processing_batches/batch_304_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 305/26519
# Batch 305 saved to /home/opc/datasets/detail/processing_batches/batch_305_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 306/26519
# Batch 306 saved to /home/opc/datasets/detail/processing_batches/batch_306_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 307/26519
# Batch 307 saved to /home/opc/datasets/detail/processing_batches/batch_307_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 308/26519
# Batch 308 saved to /home/opc/datasets/detail/processing_batches/batch_308_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 309/26519
# Batch 309 saved to /home/opc/datasets/detail/processing_batches/batch_309_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 310/26519
# Batch 310 saved to /home/opc/datasets/detail/processing_batches/batch_310_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 311/26519
# Batch 311 saved to /home/opc/datasets/detail/processing_batches/batch_311_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 312/26519
# Batch 312 saved to /home/opc/datasets/detail/processing_batches/batch_312_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 313/26519
# Batch 313 saved to /home/opc/datasets/detail/processing_batches/batch_313_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 314/26519
# Batch 314 saved to /home/opc/datasets/detail/processing_batches/batch_314_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 315/26519
# Batch 315 saved to /home/opc/datasets/detail/processing_batches/batch_315_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 316/26519
# Batch 316 saved to /home/opc/datasets/detail/processing_batches/batch_316_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 317/26519
# Batch 317 saved to /home/opc/datasets/detail/processing_batches/batch_317_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 318/26519
# Batch 318 saved to /home/opc/datasets/detail/processing_batches/batch_318_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 319/26519
# Batch 319 saved to /home/opc/datasets/detail/processing_batches/batch_319_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 320/26519
# Batch 320 saved to /home/opc/datasets/detail/processing_batches/batch_320_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 321/26519
# Batch 321 saved to /home/opc/datasets/detail/processing_batches/batch_321_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 322/26519
# Batch 322 saved to /home/opc/datasets/detail/processing_batches/batch_322_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 323/26519
# Batch 323 saved to /home/opc/datasets/detail/processing_batches/batch_323_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 324/26519
# Batch 324 saved to /home/opc/datasets/detail/processing_batches/batch_324_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 325/26519
# Batch 325 saved to /home/opc/datasets/detail/processing_batches/batch_325_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 326/26519
# Batch 326 saved to /home/opc/datasets/detail/processing_batches/batch_326_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# ...
# Batch 26417 saved to /home/opc/datasets/detail/processing_batches/batch_26417_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26418/26519
# Batch 26418 saved to /home/opc/datasets/detail/processing_batches/batch_26418_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26419/26519
# Batch 26419 saved to /home/opc/datasets/detail/processing_batches/batch_26419_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26420/26519
# Batch 26420 saved to /home/opc/datasets/detail/processing_batches/batch_26420_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26421/26519
# Batch 26421 saved to /home/opc/datasets/detail/processing_batches/batch_26421_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26422/26519
# Batch 26422 saved to /home/opc/datasets/detail/processing_batches/batch_26422_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26423/26519
# Batch 26423 saved to /home/opc/datasets/detail/processing_batches/batch_26423_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26424/26519
# Batch 26424 saved to /home/opc/datasets/detail/processing_batches/batch_26424_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26425/26519
# Batch 26425 saved to /home/opc/datasets/detail/processing_batches/batch_26425_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26426/26519
# Batch 26426 saved to /home/opc/datasets/detail/processing_batches/batch_26426_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26427/26519
# Batch 26427 saved to /home/opc/datasets/detail/processing_batches/batch_26427_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26428/26519
# Batch 26428 saved to /home/opc/datasets/detail/processing_batches/batch_26428_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26429/26519
# Batch 26429 saved to /home/opc/datasets/detail/processing_batches/batch_26429_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26430/26519
# Batch 26430 saved to /home/opc/datasets/detail/processing_batches/batch_26430_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26431/26519
# Batch 26431 saved to /home/opc/datasets/detail/processing_batches/batch_26431_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26432/26519
# Batch 26432 saved to /home/opc/datasets/detail/processing_batches/batch_26432_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26433/26519
# Batch 26433 saved to /home/opc/datasets/detail/processing_batches/batch_26433_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26434/26519
# Batch 26434 saved to /home/opc/datasets/detail/processing_batches/batch_26434_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26435/26519
# Batch 26435 saved to /home/opc/datasets/detail/processing_batches/batch_26435_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26436/26519
# Batch 26436 saved to /home/opc/datasets/detail/processing_batches/batch_26436_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26437/26519
# Batch 26437 saved to /home/opc/datasets/detail/processing_batches/batch_26437_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26438/26519
# Batch 26438 saved to /home/opc/datasets/detail/processing_batches/batch_26438_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26439/26519
# Batch 26439 saved to /home/opc/datasets/detail/processing_batches/batch_26439_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26440/26519
# Batch 26440 saved to /home/opc/datasets/detail/processing_batches/batch_26440_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26441/26519
# Batch 26441 saved to /home/opc/datasets/detail/processing_batches/batch_26441_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26442/26519
# Batch 26442 saved to /home/opc/datasets/detail/processing_batches/batch_26442_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26443/26519
# Batch 26443 saved to /home/opc/datasets/detail/processing_batches/batch_26443_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26444/26519
# Batch 26444 saved to /home/opc/datasets/detail/processing_batches/batch_26444_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26445/26519
# Batch 26445 saved to /home/opc/datasets/detail/processing_batches/batch_26445_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26446/26519
# Batch 26446 saved to /home/opc/datasets/detail/processing_batches/batch_26446_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26447/26519
# Batch 26447 saved to /home/opc/datasets/detail/processing_batches/batch_26447_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26448/26519
# Batch 26448 saved to /home/opc/datasets/detail/processing_batches/batch_26448_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26449/26519
# Batch 26449 saved to /home/opc/datasets/detail/processing_batches/batch_26449_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26450/26519
# Batch 26450 saved to /home/opc/datasets/detail/processing_batches/batch_26450_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26451/26519
# Batch 26451 saved to /home/opc/datasets/detail/processing_batches/batch_26451_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26452/26519
# Batch 26452 saved to /home/opc/datasets/detail/processing_batches/batch_26452_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26453/26519
# Batch 26453 saved to /home/opc/datasets/detail/processing_batches/batch_26453_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26454/26519
# Batch 26454 saved to /home/opc/datasets/detail/processing_batches/batch_26454_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26455/26519
# Batch 26455 saved to /home/opc/datasets/detail/processing_batches/batch_26455_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26456/26519
# Batch 26456 saved to /home/opc/datasets/detail/processing_batches/batch_26456_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26457/26519
# Batch 26457 saved to /home/opc/datasets/detail/processing_batches/batch_26457_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26458/26519
# Batch 26458 saved to /home/opc/datasets/detail/processing_batches/batch_26458_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26459/26519
# Batch 26459 saved to /home/opc/datasets/detail/processing_batches/batch_26459_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26460/26519
# Batch 26460 saved to /home/opc/datasets/detail/processing_batches/batch_26460_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26461/26519
# Batch 26461 saved to /home/opc/datasets/detail/processing_batches/batch_26461_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26462/26519
# Batch 26462 saved to /home/opc/datasets/detail/processing_batches/batch_26462_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26463/26519
# Batch 26463 saved to /home/opc/datasets/detail/processing_batches/batch_26463_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26464/26519
# Batch 26464 saved to /home/opc/datasets/detail/processing_batches/batch_26464_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26465/26519
# Batch 26465 saved to /home/opc/datasets/detail/processing_batches/batch_26465_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26466/26519
# Batch 26466 saved to /home/opc/datasets/detail/processing_batches/batch_26466_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26467/26519
# Batch 26467 saved to /home/opc/datasets/detail/processing_batches/batch_26467_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26468/26519
# Batch 26468 saved to /home/opc/datasets/detail/processing_batches/batch_26468_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26469/26519
# Batch 26469 saved to /home/opc/datasets/detail/processing_batches/batch_26469_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26470/26519
# Batch 26470 saved to /home/opc/datasets/detail/processing_batches/batch_26470_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26471/26519
# Batch 26471 saved to /home/opc/datasets/detail/processing_batches/batch_26471_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26472/26519
# Batch 26472 saved to /home/opc/datasets/detail/processing_batches/batch_26472_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26473/26519
# Batch 26473 saved to /home/opc/datasets/detail/processing_batches/batch_26473_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26474/26519
# Batch 26474 saved to /home/opc/datasets/detail/processing_batches/batch_26474_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26475/26519
# Batch 26475 saved to /home/opc/datasets/detail/processing_batches/batch_26475_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26476/26519
# Batch 26476 saved to /home/opc/datasets/detail/processing_batches/batch_26476_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26477/26519
# Batch 26477 saved to /home/opc/datasets/detail/processing_batches/batch_26477_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26478/26519
# Batch 26478 saved to /home/opc/datasets/detail/processing_batches/batch_26478_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26479/26519
# Batch 26479 saved to /home/opc/datasets/detail/processing_batches/batch_26479_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26480/26519
# Batch 26480 saved to /home/opc/datasets/detail/processing_batches/batch_26480_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26481/26519
# Batch 26481 saved to /home/opc/datasets/detail/processing_batches/batch_26481_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26482/26519
# Batch 26482 saved to /home/opc/datasets/detail/processing_batches/batch_26482_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26483/26519
# Batch 26483 saved to /home/opc/datasets/detail/processing_batches/batch_26483_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26484/26519
# Batch 26484 saved to /home/opc/datasets/detail/processing_batches/batch_26484_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26485/26519
# Batch 26485 saved to /home/opc/datasets/detail/processing_batches/batch_26485_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26486/26519
# Batch 26486 saved to /home/opc/datasets/detail/processing_batches/batch_26486_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26487/26519
# Batch 26487 saved to /home/opc/datasets/detail/processing_batches/batch_26487_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26488/26519
# Batch 26488 saved to /home/opc/datasets/detail/processing_batches/batch_26488_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26489/26519
# Batch 26489 saved to /home/opc/datasets/detail/processing_batches/batch_26489_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26490/26519
# Batch 26490 saved to /home/opc/datasets/detail/processing_batches/batch_26490_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26491/26519
# Batch 26491 saved to /home/opc/datasets/detail/processing_batches/batch_26491_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26492/26519
# Batch 26492 saved to /home/opc/datasets/detail/processing_batches/batch_26492_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26493/26519
# Batch 26493 saved to /home/opc/datasets/detail/processing_batches/batch_26493_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26494/26519
# Batch 26494 saved to /home/opc/datasets/detail/processing_batches/batch_26494_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26495/26519
# Batch 26495 saved to /home/opc/datasets/detail/processing_batches/batch_26495_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26496/26519
# Batch 26496 saved to /home/opc/datasets/detail/processing_batches/batch_26496_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26497/26519
# Batch 26497 saved to /home/opc/datasets/detail/processing_batches/batch_26497_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26498/26519
# Batch 26498 saved to /home/opc/datasets/detail/processing_batches/batch_26498_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26499/26519
# Batch 26499 saved to /home/opc/datasets/detail/processing_batches/batch_26499_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26500/26519
# Batch 26500 saved to /home/opc/datasets/detail/processing_batches/batch_26500_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26501/26519
# Batch 26501 saved to /home/opc/datasets/detail/processing_batches/batch_26501_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26502/26519
# Batch 26502 saved to /home/opc/datasets/detail/processing_batches/batch_26502_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26503/26519
# Batch 26503 saved to /home/opc/datasets/detail/processing_batches/batch_26503_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26504/26519
# Batch 26504 saved to /home/opc/datasets/detail/processing_batches/batch_26504_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26505/26519
# Batch 26505 saved to /home/opc/datasets/detail/processing_batches/batch_26505_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26506/26519
# Batch 26506 saved to /home/opc/datasets/detail/processing_batches/batch_26506_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26507/26519
# Batch 26507 saved to /home/opc/datasets/detail/processing_batches/batch_26507_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26508/26519
# Batch 26508 saved to /home/opc/datasets/detail/processing_batches/batch_26508_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26509/26519
# Batch 26509 saved to /home/opc/datasets/detail/processing_batches/batch_26509_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26510/26519
# Batch 26510 saved to /home/opc/datasets/detail/processing_batches/batch_26510_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26511/26519
# Batch 26511 saved to /home/opc/datasets/detail/processing_batches/batch_26511_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26512/26519
# Batch 26512 saved to /home/opc/datasets/detail/processing_batches/batch_26512_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26513/26519
# Batch 26513 saved to /home/opc/datasets/detail/processing_batches/batch_26513_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26514/26519
# Batch 26514 saved to /home/opc/datasets/detail/processing_batches/batch_26514_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26515/26519
# Batch 26515 saved to /home/opc/datasets/detail/processing_batches/batch_26515_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26516/26519
# Batch 26516 saved to /home/opc/datasets/detail/processing_batches/batch_26516_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26517/26519
# Batch 26517 saved to /home/opc/datasets/detail/processing_batches/batch_26517_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26518/26519
# Batch 26518 saved to /home/opc/datasets/detail/processing_batches/batch_26518_of_26519.pkl
#   Exploded from 2500 to 2500 rows
# Processing batch 26519/26519
# Batch 26519 saved to /home/opc/datasets/detail/processing_batches/batch_26519_of_26519.pkl
#   Exploded from 724 to 724 rows
# Combining all batches...
# Combined dataset shape: (66295724, 6)
# Combined data saved to /home/opc/datasets/detail/geo_data_preprocessed.pkl
# Step 2 completed successfully!

# %% [markdown]
# <h3><strong>STEP 3: Decode Geohashes and Prepare for Feature Engineering</strong></h3>

# %%
# Check the processed PKL file before Step 3
import pandas as pd
import numpy as np
import os

PROCESSED_PATH = "/home/opc/TAP/models/notebooks/geo_data_preprocessed.pkl"  # update if you saved elsewhere

def inspect_processed_data(file_path=PROCESSED_PATH):
    """
    Inspect the processed data to verify the explosion was done correctly
    """
    try:
        if not os.path.exists(file_path):
            print(f"File not found: {file_path}")
            return None

        geo_df_processed = pd.read_pickle(file_path)
        n = len(geo_df_processed)
        print(f"Successfully loaded processed data with {n} rows")

        if n == 0:
            print("Dataset is empty")
            return geo_df_processed

        print("\n=== DATASET INFO ===")
        print(geo_df_processed.info())

        print("\n=== FIRST 10 ROWS ===")
        print(geo_df_processed.head(10))

        print("\n=== GEOHASH COLUMNS CHECK ===")
        for col in ['geohash_4', 'geohash_5', 'geohash_6']:
            if col not in geo_df_processed.columns:
                print(f"{col}: column missing")
                continue
            # find a non null sample if possible
            sample_idx = geo_df_processed[col].first_valid_index()
            sample_value = geo_df_processed[col].iloc[0] if sample_idx is None else geo_df_processed.at[sample_idx, col]
            print(f"{col}: {type(sample_value)}, sample: {sample_value}")
            if isinstance(sample_value, (list, np.ndarray)):
                print(f"  WARNING: {col} still contains arrays")
            else:
                print(f"  OK: {col} contains individual values")

        print("\n=== DATA TYPES ===")
        print(geo_df_processed.dtypes)

        print("\n=== MISSING VALUES ===")
        print(geo_df_processed.isnull().sum())

        return geo_df_processed

    except Exception as e:
        print(f"Error loading file: {e}")
        return None

# Execute the inspection
processed_data = inspect_processed_data(PROCESSED_PATH)

# If the data still has arrays, we need to fix it before proceeding
if processed_data is not None and len(processed_data) > 0:
    has_arrays = False
    for col in ['geohash_4', 'geohash_5', 'geohash_6']:
        if col in processed_data.columns:
            sample_idx = processed_data[col].first_valid_index()
            if sample_idx is None:
                continue
            sample = processed_data.at[sample_idx, col]
            if isinstance(sample, (list, np.ndarray)):
                has_arrays = True
                print(f"\nERROR: {col} still contains arrays. Step 2 did not work correctly.")
    if has_arrays:
        print("The current data still has arrays in the geohash columns, cannot decode yet.")
    else:
        print("\nData looks good, proceed to Step 3.")
# Out:
# File not found: /home/opc/TAP/models/notebooks/geo_data_preprocessed.pkl

# %%
import pandas as pd
import numpy as np
import os
from tqdm.auto import tqdm
import pygeohash as gh  # pip install pygeohash


# paths, adjust if you saved elsewhere
PROCESSED_IN  = "/home/opc/TAP/models/notebooks/geo_data_preprocessed.pkl"
PROCESSED_OUT = "/home/opc/TAP/models/notebooks/geo_data_fully_processed.pkl"

alphabet = set("0123456789bcdefghjkmnpqrstuvwxyz")
def looks_like_geohash(v):
    if pd.isna(v):
        return False
    s = str(v).strip().lower()
    if len(s) == 0 or len(s) > 12:
        return False
    return set(s).issubset(alphabet)

def decode_one(val):
    if not looks_like_geohash(val):
        return (np.nan, np.nan)
    try:
        return gh.decode(str(val).strip())
    except Exception:
        return (np.nan, np.nan)

def decode_geohashes_batch(geo_df_exploded, batch_size=100_000, output_file=PROCESSED_OUT):
    print("STEP 3, decoding geohashes and preparing data")
    total_rows = len(geo_df_exploded)
    num_batches = (total_rows + batch_size - 1) // batch_size
    print(f"Processing {total_rows} rows in {num_batches} batches of size {batch_size}")

    processed_batches = []
    total_dropped = 0

    for batch_num in range(num_batches):
        print(f"Processing batch {batch_num + 1}/{num_batches}")
        start_idx = batch_num * batch_size
        end_idx = min((batch_num + 1) * batch_size, total_rows)
        batch_df = geo_df_exploded.iloc[start_idx:end_idx].copy()

        # single pass decode with progress bar
        tqdm.pandas(desc="Decoding geohash_6")
        coords = batch_df["geohash_6"].progress_apply(decode_one)
        batch_df["latitude"]  = coords.apply(lambda t: t[0])
        batch_df["longitude"] = coords.apply(lambda t: t[1])

        # drop invalid coordinates
        before = len(batch_df)
        batch_df = batch_df.dropna(subset=["latitude", "longitude"])
        dropped = before - len(batch_df)
        total_dropped += dropped
        if dropped > 0:
            pct = 100.0 * dropped / max(1, before)
            print(f"  Dropped {dropped} rows with invalid coordinates [{pct:.1f} percent]")

        processed_batches.append(batch_df)
        del batch_df, coords

    geo_df_processed = pd.concat(processed_batches, ignore_index=True)
    geo_df_processed = geo_df_processed.sort_values(["client_id", "event_time"])
    print(f"Final dataset shape: {geo_df_processed.shape}")
    print(f"Total dropped rows: {total_dropped} [{100.0 * total_dropped / max(1, total_rows):.1f} percent]")

    # save
    out_dir = os.path.dirname(output_file)
    if out_dir:
        os.makedirs(out_dir, exist_ok=True)
    geo_df_processed.to_pickle(output_file)
    print(f"Fully processed data saved to {output_file}")

    return geo_df_processed

def analyze_processed_data(geo_df_processed):
    print("\n=== DATA ANALYSIS ===")
    print(f"Total events: {len(geo_df_processed):,}")
    print(f"Unique clients: {geo_df_processed['client_id'].nunique():,}")
    min_time = geo_df_processed['event_time'].min()
    max_time = geo_df_processed['event_time'].max()
    print(f"Time range: {min_time} to {max_time}")
    print(f"Duration: {max_time - min_time}")
    events_per_client = geo_df_processed.groupby('client_id').size()
    print(f"Average events per client: {events_per_client.mean():.1f}")
    print(f"Min events per client: {events_per_client.min()}")
    print(f"Max events per client: {events_per_client.max()}")
    print(f"Latitude range: {geo_df_processed['latitude'].min():.4f} to {geo_df_processed['latitude'].max():.4f}")
    print(f"Longitude range: {geo_df_processed['longitude'].min():.4f} to {geo_df_processed['longitude'].max():.4f}")
    return events_per_client

# run
geo_df_exploded = pd.read_pickle(PROCESSED_IN)
print(f"Loaded preprocessed data with {len(geo_df_exploded):,} rows")

# tune batch_size smaller if memory is limited, for example 25_000
geo_df_processed = decode_geohashes_batch(geo_df_exploded, batch_size=100_000, output_file=PROCESSED_OUT)
events_per_client = analyze_processed_data(geo_df_processed)

print("\nSample of processed data:")
print(geo_df_processed[['client_id', 'event_time', 'geohash_6', 'latitude', 'longitude', 'fold']].head(10))
print("\nStep 3 completed successfully, ready for feature engineering in Step 4")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 4
#       2 import numpy as np
#       3 import os
# ----> 4 from tqdm.auto import tqdm
#       5 import pygeohash as gh  # pip install pygeohash
#       8 # paths, adjust if you saved elsewhere
#
# ModuleNotFoundError: No module named 'tqdm'

# %%
# Step 3 Results Inspection
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def inspect_step3_results(file_path="/home/opc/TAP/models/notebooks/geo_data_fully_processed.pkl", sample_size=10000):
    """
    Comprehensive inspection of Step 3 results
    """
    print("=== STEP 3 RESULTS INSPECTION ===")
    
    try:
        # Load the processed data
        geo_df_processed = pd.read_pickle(file_path)
        print(f"Loaded processed data with {len(geo_df_processed):,} rows")
        
        # 1. Basic Information
        print("\n1. BASIC DATASET INFO:")
        print(f"Shape: {geo_df_processed.shape}")
        print("\nColumns and data types:")
        print(geo_df_processed.dtypes)
        
        # 2. Check for missing values
        print("\n2. MISSING VALUES CHECK:")
        missing_values = geo_df_processed.isnull().sum()
        print(missing_values)
        
        # 3. Verify coordinate ranges
        print("\n3. COORDINATE RANGES:")
        print(f"Latitude range: [{geo_df_processed['latitude'].min():.6f}, {geo_df_processed['latitude'].max():.6f}]")
        print(f"Longitude range: [{geo_df_processed['longitude'].min():.6f}, {geo_df_processed['longitude'].max():.6f}]")
        
        # 4. Sample of decoded coordinates
        print("\n4. SAMPLE OF DECODED COORDINATES:")
        sample_df = geo_df_processed.sample(min(sample_size, len(geo_df_processed)))
        print(sample_df[['geohash_6', 'latitude', 'longitude']].head(10))
        
        # 5. Check coordinate distribution
        print("\n5. COORDINATE DISTRIBUTION:")
        fig, axes = plt.subplots(1, 2, figsize=(12, 5))
        
        # Latitude distribution
        sns.histplot(geo_df_processed['latitude'].dropna(), ax=axes[0], kde=True)
        axes[0].set_title('Latitude Distribution')
        
        # Longitude distribution
        sns.histplot(geo_df_processed['longitude'].dropna(), ax=axes[1], kde=True)
        axes[1].set_title('Longitude Distribution')
        
        plt.tight_layout()
        plt.savefig('coordinate_distribution.png')
        print("Coordinate distribution plots saved as 'coordinate_distribution.png'")
        
        # 6. Check for impossible coordinates
        print("\n6. IMPOSSIBLE COORDINATE CHECK:")
        # Check for coordinates that are clearly invalid
        invalid_lat = ((geo_df_processed['latitude'] < -90) | (geo_df_processed['latitude'] > 90)).sum()
        invalid_lon = ((geo_df_processed['longitude'] < -180) | (geo_df_processed['longitude'] > 180)).sum()
        print(f"Invalid latitudes (outside [-90, 90]): {invalid_lat}")
        print(f"Invalid longitudes (outside [-180, 180]): {invalid_lon}")
        
        # 7. Check for coordinates that are exactly 0,0 (often indicates decoding errors)
        zero_coords = ((geo_df_processed['latitude'] == 0) & (geo_df_processed['longitude'] == 0)).sum()
        print(f"Coordinates at (0, 0): {zero_coords}")
        
        # 8. Check client distribution
        print("\n7. CLIENT DISTRIBUTION:")
        client_counts = geo_df_processed['client_id'].value_counts()
        print(f"Total clients: {len(client_counts):,}")
        print(f"Average events per client: {client_counts.mean():.1f}")
        print(f"Min events per client: {client_counts.min()}")
        print(f"Max events per client: {client_counts.max()}")
        
        # 9. Time range check
        print("\n8. TIME RANGE:")
        print(f"Earliest event: {geo_df_processed['event_time'].min()}")
        print(f"Latest event: {geo_df_processed['event_time'].max()}")
        
        # 10. Fold distribution
        print("\n9. FOLD DISTRIBUTION:")
        fold_counts = geo_df_processed['fold'].value_counts().sort_index()
        print(fold_counts)
        
        return geo_df_processed
        
    except FileNotFoundError:
        print(f"File {file_path} not found. Please run Step 3 first.")
        return None
    except Exception as e:
        print(f"Error during inspection: {e}")
        return None

# Execute the inspection
processed_data = inspect_step3_results()

if processed_data is not None:
    print("\n=== INSPECTION COMPLETE ===")
    print("Based on this inspection, we can determine if Step 3 was successful")
    print("and whether we can proceed to Step 4 (Feature Engineering).")
    
    # Check if there are any critical issues that need to be addressed
    missing_coords = processed_data[['latitude', 'longitude']].isnull().sum().sum()
    if missing_coords > 0:
        print(f"\nWARNING: Found {missing_coords} missing coordinates. This might affect feature engineering.")
    
    invalid_coords = ((processed_data['latitude'] < -90) | (processed_data['latitude'] > 90) | 
                     (processed_data['longitude'] < -180) | (processed_data['longitude'] > 180)).sum()
    if invalid_coords > 0:
        print(f"WARNING: Found {invalid_coords} invalid coordinates outside valid ranges.")
    
    if missing_coords == 0 and invalid_coords == 0:
        print("\n✓ Step 3 completed successfully. Data is ready for Step 4 (Feature Engineering).")
    else:
        print("\n⚠ Step 3 completed with some issues. We may need to clean the data before Step 4.")
